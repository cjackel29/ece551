# %% [markdown]
# <br>
# Title: Timeseries satellite telemetry anomaly detection using an Autoencoder<br>
# Author: Chuck Jackel - based on original code by Pavithra Vijay [pavithrasv](https://github.com/pavithrasv)<br>
# using Vijay's tutorial from 2020 at https://keras.io/examples/timeseries/timeseries_anomaly_detection/<br>
# Date created: 2022/10/6/2022<br>
# Last modified: 2022/10/14/2022<br>
# Description: Detect anomalies in a satellite telemetry timeseries using an Autoencoder.<br>

# %% [markdown]
# <br>Introduction<br>
# This script demonstrates how to use a reconstruction convolutional<br>
# autoencoder model to detect anomalies in timeseries satellite telemetry data.<br>

# %% [markdown]
# <br>Setup<br>
# <br>The python hash seed and random seeds were set to ensure this code can be repeatedly executed
# with the same results.<br>

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from pandas import read_csv
import tensorflow as tf
import random as python_random

from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

PYTHONHASHSEED=0

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.
np.random.seed(222)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.
python_random.seed(222)

# The below set_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/random/set_seed
tf.random.set_seed(333)
# Out:
# 2022-10-14 19:43:03.134078: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-14 19:43:03.387944: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-14 19:43:03.387964: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-14 19:43:03.433157: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-14 19:43:04.205197: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-14 19:43:04.205306: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-14 19:43:04.205315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# <br>Load the data<br><br>
# Satellite bus voltage telemetry from the Laboratory for Atmospheric Sciences and Physics (LASP) at University of Colorado Boulder is used for this demonstration. The data is located on Shawn Polson's github page at https://github.com/sapols/Satellite-Telemetry-Anomaly-Detection/tree/master/Data. <br>
# <br> It is unknown if any of the data is anomalous. However, there are spikes in the data that suggest possible anomalies, so the various experiments with data preparation impacted how the model performed.<br>
# <br>In this demonstration, the latter 2/3 section of the original data was used to train the model. This was done to eliminate the 20 volt spike near the year 2005 as part of the training data.<br>

# %%
master_url_root = "https://raw.githubusercontent.com/cjackel29/ece551/"

# %%
#df_small_noise_url_suffix = "main/busvoltage_without_anomaly.csv"
df_small_noise_url_suffix = "main/busvoltage_smoothed_end_112707.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(df_small_noise_url, parse_dates=True, index_col=0)
df_small_noise_original = df_small_noise
df_small_noise_section = df_small_noise[:10000] # smoothed bus voltage from 2001 to 2005
#df_small_noise_section = df_small_noise[37570:44870] # smoothed bus voltage from early-2014 to mid-2016
df_small_noise_original = df_small_noise
df_small_noise = df_small_noise_section

# %%
df_daily_jumpsup_url_suffix = "main/busvoltage_without_anomaly.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(df_daily_jumpsup_url, parse_dates=True, index_col=0)
df_daily_jumpsup_original = df_daily_jumpsup
df_daily_jumpsup_section = df_daily_jumpsup[:20009] # bus voltage from 2001 to 2008
#df_daily_jumpsup_section = df_daily_jumpsup[37570:] # bus voltage from early-2014 to 2018
df_daily_jumpsup = df_daily_jumpsup_section

# %%
print(df_small_noise.head())
df_small_noise.shape
# Out:
#                      busvoltage
# datetime
# 2001-01-21 21:00:00   32.003189
# 2001-01-22 00:00:00   31.943952
# 2001-01-22 03:00:00   32.102344
# 2001-01-22 06:00:00   31.988111
# 2001-01-22 09:00:00   31.945055
# (10000, 1)

# %%
print(df_daily_jumpsup.head())
df_daily_jumpsup.shape
# Out:
#                      busvoltage
# datetime
# 2001-01-21 21:00:00   32.003189
# 2001-01-22 00:00:00   31.943952
# 2001-01-22 03:00:00   32.102344
# 2001-01-22 06:00:00   31.988111
# 2001-01-22 09:00:00   31.945055
# (20009, 1)

# %%
fig, ax = plt.subplots()
df_daily_jumpsup_original.plot(ax=ax)
plt.legend(["Unmodified original bus voltage telemetry from 2001 to 2018"])
plt.ylim(18,36)
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()

# %% [markdown]
# <br>The satellite telemetry from approximately 2008 through 2018 is used for training data.<br>

# %%
fig, ax = plt.subplots()
df_small_noise.plot(ax=ax)
plt.legend(["Training data is {}% of testing data".format(int(100*df_small_noise.shape[0]/df_daily_jumpsup.shape[0]))])
plt.ylim(18,35)
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()

# %% [markdown]
# <br>The entire satellite bus voltage telemetry from 2001 to 2018 has numerous spikes including a 20 volt drop near 2005. Let us see if the model will detect any of the spikes as an anomaly.<br>

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(ax=ax)
plt.legend(["Testing data is {}% of original data".format(int(100*df_daily_jumpsup_section.shape[0]/51704))])
plt.ylim(18,35)
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()

# %% [markdown]
# <br>Prepare training data<br><br>
# Get data values from the training timeseries data file and normalize the<br>
# `value` data. We have a `value` for every 3 hours for about 18 years.<br>
# -   24 hours / 3 hours = 8 timesteps per day<br>
# -  8 x 365 x 18 = 52560 data points in total<br>
# - Our dataset is 51704 data points, which is about 17.7 years total.<br>

# %% [markdown]
# Normalize the data by using the standardize method to create standard scores.<br><br>
# The formula is:<br><br>
# standard score = (original value - mean of entire dataset) / standard deviation of entire dataset<br>

# %%
training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
df_training_value = (df_small_noise - training_mean) / training_std
print("Number of training samples:", len(df_training_value))
# Out:
# Number of training samples: 10000

# %% [markdown]
# <br>Create sequences<br><br>
# Create sequences combining `TIME_STEPS` contiguous data values from the<br>
# training data.<br>

# %%
TIME_STEPS = 8 # each measurement is taken every 3 hours, so there are 8 samples per day, 56 samples per week, 2912 per year

# %% [markdown]
# Generated training sequences for use in the model.

# %%
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)

# %%
x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (9993, 8, 1)

# %% [markdown]
# <br>Build a model<br><br>
# We will build a convolutional reconstruction autoencoder model. The model will<br>
# take input of shape `(batch_size, sequence_length, num_features)` and return<br>
# output of the same shape. In this case, `sequence_length` is 8 and<br>
# `num_features` is 1.<br>

# %%
model = keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
        layers.Conv1D(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1D(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 32)             256
#
#  dropout (Dropout)           (None, 4, 32)             0
#
#  conv1d_1 (Conv1D)           (None, 2, 16)             3600
#
#  conv1d_transpose (Conv1DTra  (None, 4, 16)            1808
#  nspose)
#
#  dropout_1 (Dropout)         (None, 4, 16)             0
#
#  conv1d_transpose_1 (Conv1DT  (None, 8, 32)            3616
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 8, 1)             225
#  ranspose)
#
# =================================================================
# Total params: 9,505
# Trainable params: 9,505
# Non-trainable params: 0
# _________________________________________________________________
# 2022-10-14 19:43:13.436293: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-10-14 19:43:13.436348: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-14 19:43:13.436371: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ubuntu): /proc/driver/nvidia/version does not exist
# 2022-10-14 19:43:13.436705: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# <br>Train the model<br><br>
# Please note that we are using `x_train` as both the input and the target<br>
# since this is a reconstruction model.<br>

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=100,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, mode="min")
    ],
)
# Out:
# Epoch 1/100
# 71/71 [==============================] - 1s 10ms/step - loss: 0.4240 - val_loss: 0.0174
# Epoch 2/100
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0834 - val_loss: 0.0117
# Epoch 3/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0762 - val_loss: 0.0103
# Epoch 4/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0093
# Epoch 5/100
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0684 - val_loss: 0.0091
# Epoch 6/100
# 71/71 [==============================] - 1s 8ms/step - loss: 0.0643 - val_loss: 0.0088
# Epoch 7/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0574 - val_loss: 0.0086
# Epoch 8/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0524 - val_loss: 0.0086
# Epoch 9/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0484 - val_loss: 0.0083
# Epoch 10/100
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0445 - val_loss: 0.0081
# Epoch 11/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0413 - val_loss: 0.0077
# Epoch 12/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0367 - val_loss: 0.0077
# Epoch 13/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0344 - val_loss: 0.0075
# Epoch 14/100
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0067
# Epoch 15/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0277 - val_loss: 0.0064
# Epoch 16/100
# 71/71 [==============================] - 1s 8ms/step - loss: 0.0279 - val_loss: 0.0063
# Epoch 17/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0263 - val_loss: 0.0058
# Epoch 18/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0244 - val_loss: 0.0052
# Epoch 19/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0230 - val_loss: 0.0050
# Epoch 20/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0225 - val_loss: 0.0049
# Epoch 21/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0219 - val_loss: 0.0054
# Epoch 22/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0208 - val_loss: 0.0038
# Epoch 23/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0196 - val_loss: 0.0035
# Epoch 24/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0190 - val_loss: 0.0035
# Epoch 25/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0186 - val_loss: 0.0031
# Epoch 26/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0189 - val_loss: 0.0029
# Epoch 27/100
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0180 - val_loss: 0.0030
# Epoch 28/100
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0173 - val_loss: 0.0026
# Epoch 29/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0027
# Epoch 30/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0165 - val_loss: 0.0029
# Epoch 31/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0023
# Epoch 32/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0022
# Epoch 33/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0169 - val_loss: 0.0023
# Epoch 34/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0154 - val_loss: 0.0023
# Epoch 35/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0152 - val_loss: 0.0022
# Epoch 36/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0030
# Epoch 37/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0159 - val_loss: 0.0023
# Epoch 38/100
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0143 - val_loss: 0.0021
# Epoch 39/100
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0152 - val_loss: 0.0022
# Epoch 40/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0143 - val_loss: 0.0022
# Epoch 41/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0024
# Epoch 42/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0020
# Epoch 43/100
# 71/71 [==============================] - 1s 9ms/step - loss: 0.0135 - val_loss: 0.0024
# Epoch 44/100
# 71/71 [==============================] - 1s 9ms/step - loss: 0.0141 - val_loss: 0.0023
# Epoch 45/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0018
# Epoch 46/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0023
# Epoch 47/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0129 - val_loss: 0.0020
# Epoch 48/100
# 71/71 [==============================] - 1s 8ms/step - loss: 0.0136 - val_loss: 0.0018
# Epoch 49/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0019
# Epoch 50/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0019
# Epoch 51/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0020
# Epoch 52/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0126 - val_loss: 0.0018
# Epoch 53/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0021
# Epoch 54/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0021
# Epoch 55/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0017
# Epoch 56/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0022
# Epoch 57/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0020
# Epoch 58/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0022
# Epoch 59/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0018
# Epoch 60/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0020
# Epoch 61/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0018
# Epoch 62/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0019
# Epoch 63/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0019
# Epoch 64/100
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.0023
# Epoch 65/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0020
# Epoch 66/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0021
# Epoch 67/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0021
# Epoch 68/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0018
# Epoch 69/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0026
# Epoch 70/100
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0024
# Epoch 71/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0020
# Epoch 72/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0022
# Epoch 73/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0115 - val_loss: 0.0017
# Epoch 74/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.0020
# Epoch 75/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0025
# Epoch 76/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0021
# Epoch 77/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0023
# Epoch 78/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.0027
# Epoch 79/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0022
# Epoch 80/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0023
# Epoch 81/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0029
# Epoch 82/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0105 - val_loss: 0.0028
# Epoch 83/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 0.0034
# Epoch 84/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0022
# Epoch 85/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.0023
# Epoch 86/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0025
# Epoch 87/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0035
# Epoch 88/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0022
# Epoch 89/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0028
# Epoch 90/100
# 71/71 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0030
# Epoch 91/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0023
# Epoch 92/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0024
# Epoch 93/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0020
# Epoch 94/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0019
# Epoch 95/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0025
# Epoch 96/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0028
# Epoch 97/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0031
# Epoch 98/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0096 - val_loss: 0.0026
# Epoch 99/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0096 - val_loss: 0.0032
# Epoch 100/100
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0097 - val_loss: 0.0030

# %% [markdown]
# <br>
# Let's plot training and validation loss to see how the training went.<br>

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# <br>Detecting anomalies<br><br>
# We will detect anomalies by determining how well our model can reconstruct<br>
# the input data.<br>
# 1.   Find Mean Absolute Error (MAE) loss on training samples.<br>
# 2.   Find max MAE loss value. This is the worst our model has performed trying<br>
# to reconstruct a sample. We will make this the `threshold` for anomaly<br>
# detection.<br>
# 3.   If the reconstruction loss for a sample is greater than this `threshold`<br>
# value then we can infer that the model is seeing a pattern that it isn't<br>
# familiar with. We will label this sample as an `anomaly`.<br>

# %% [markdown]
# Get train MAE loss.

# %%
x_train_pred = model.predict(x_train)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# %% [markdown]
# Get reconstruction loss threshold.

# %%
threshold = np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)
# Out:
# Reconstruction error threshold:  0.7298432344792264

# %% [markdown]
# <br>Compare recontruction<br>
# As a test, we can see how our model has recontructed the first sample. This is the 8 timesteps in the first 24 hours of our training dataset because a measurement is recorded once every 3 hours.<br>

# %% [markdown]
# Checking how the first sequence is learned

# %%
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# <br>Prepare test data<br>

# %%
df_test_value = (df_daily_jumpsup - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# Create sequences from test values.

# %%
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Test input shape:  (20002, 8, 1)

# %%
x_test
# Out:
# array([[[-1.3562352 ],
#         [-1.53712514],
#         [-1.05344647],
#         ...,
#         [-1.7823727 ],
#         [-1.21707518],
#         [-0.95321807]],
#
#        [[-1.53712514],
#         [-1.05344647],
#         [-1.40227654],
#         ...,
#         [-1.21707518],
#         [-0.95321807],
#         [-1.7589308 ]],
#
#        [[-1.05344647],
#         [-1.40227654],
#         [-1.53375544],
#         ...,
#         [-0.95321807],
#         [-1.7589308 ],
#         [-1.27622894]],
#
#        ...,
#
#        [[-2.52316997],
#         [-1.82543262],
#         [-2.03673862],
#         ...,
#         [-1.93392257],
#         [-1.89436042],
#         [-2.38936646]],
#
#        [[-1.82543262],
#         [-2.03673862],
#         [-2.65625992],
#         ...,
#         [-1.89436042],
#         [-2.38936646],
#         [-2.51844657]],
#
#        [[-2.03673862],
#         [-2.65625992],
#         [-2.47201375],
#         ...,
#         [-2.38936646],
#         [-2.51844657],
#         [-8.12953015]]])

# %% [markdown]
# Get test MAE loss.

# %%
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))
# Out:
# 626/626 [==============================] - 1s 2ms/step

# %%
plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# %% [markdown]
# Detect all the samples which are anomalies.

# %%
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Number of anomaly samples:  35
# Indices of anomaly samples:  (array([ 2528, 11394, 11395, 11396, 11397, 11398, 11399, 11400, 11401,
#        11402, 11403, 11404, 11405, 11406, 11407, 11408, 11409, 11410,
#        11411, 11412, 11413, 11414, 11415, 11416, 11445, 11446, 11447,
#        11448, 11449, 11450, 11451, 11452, 11453, 11454, 11455]),)

# %% [markdown]
# <br>Plot anomalies<br><br>
# We now know the samples of the data which are anomalies. With this, we will<br>
# find the corresponding `timestamps` from the original test data. We will be<br>
# using the following method to do that:<br><br>
# Let's say time_steps = 3 and we have 10 training values. Our `x_train` will<br>
# look like this:<br>
# - 0, 1, 2<br>
# - 1, 2, 3<br>
# - 2, 3, 4<br>
# - 3, 4, 5<br>
# - 4, 5, 6<br>
# - 5, 6, 7<br>
# - 6, 7, 8<br>
# - 7, 8, 9<br><br>
# All except the initial and the final time_steps-1 data values, will appear in<br>
# `time_steps` number of samples. So, if we know that the samples<br>
# [(3, 4, 5), (4, 5, 6), (5, 6, 7)] are anomalies, we can say that the data point<br>
# 5 is an anomaly.<br>

# %% [markdown]
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies

# %%
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
if len(anomalous_data_indices) == 0:
    print("No anomalies detected by model.")

# %% [markdown]
# <br>We can overlay the anomalies on the original test data plot shown in red.<br>

# %%
if len(anomalous_data_indices) > 0:
    df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]
    df_subset.columns=["Anomaly Voltage"]
    df_daily_jumpsup.columns=["Original Bus Voltage"]
    fig, ax = plt.subplots()
    df_daily_jumpsup.plot(ax=ax) # removed legend=False
    df_subset.plot(ax=ax, color="r")
    plt.legend()
    plt.ylabel("Bus Voltage (volts)")
    plt.xlabel("Time (year)")
    plt.show()

# %%
anomalous_data_indices
# Out:
# [11401,
#  11402,
#  11403,
#  11404,
#  11405,
#  11406,
#  11407,
#  11408,
#  11409,
#  11410,
#  11411,
#  11412,
#  11413,
#  11414,
#  11415,
#  11416,
#  11417,
#  11452,
#  11453,
#  11454,
#  11455,
#  11456]

# %%
df_subset
# Out:
#                      Anomaly Voltage
# datetime
# 2004-12-17 00:00:00        34.180000
# 2004-12-17 03:00:00        33.893214
# 2004-12-17 06:00:00        33.606428
# 2004-12-17 09:00:00        33.319643
# 2004-12-17 12:00:00        33.032857
# 2004-12-17 15:00:00        32.746071
# 2004-12-17 18:00:00        32.459285
# 2004-12-17 21:00:00        32.172500
# 2004-12-18 00:00:00        30.650937
# 2004-12-18 03:00:00        29.129375
# 2004-12-18 06:00:00        27.607812
# 2004-12-18 09:00:00        26.086250
# 2004-12-18 12:00:00        24.564687
# 2004-12-18 15:00:00        23.043125
# 2004-12-18 18:00:00        21.521562
# 2004-12-18 21:00:00        20.000000
# 2004-12-19 00:00:00        31.730372
# 2004-12-23 09:00:00        20.000000
# 2004-12-23 12:00:00        21.645083
# 2004-12-23 15:00:00        23.290167
# 2004-12-23 18:00:00        24.935250
# 2004-12-23 21:00:00        28.481537

# %%
x_train.shape[0], x_train.shape[1], x_train.shape[2]
# Out:
# (9993, 8, 1)

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Experiment 2 with a different section of the bus voltage

# %% [markdown]
# <br>Introduction<br>
# This script demonstrates how to use a reconstruction convolutional<br>
# autoencoder model to detect anomalies in timeseries satellite telemetry data.<br>

# %% [markdown]
# <br>Load the data<br><br>
# Satellite bus voltage telemetry from the Laboratory for Atmospheric Sciences and Physics (LASP) at University of Colorado Boulder is used for this demonstration. The data is located on Shawn Polson's github page at https://github.com/sapols/Satellite-Telemetry-Anomaly-Detection/tree/master/Data. <br>
# <br> It is unknown if any of the data is anomalous. However, there are spikes in the data that suggest possible anomalies, so the various experiments with data preparation impacted how the model performed.<br>
# <br>In this demonstration, the latter 2/3 section of the original data was used to train the model. This was done to eliminate the 20 volt spike near the year 2005 as part of the training data.<br>

# %%
df_subset_first = df_subset

# %%
master_url_root = "https://raw.githubusercontent.com/cjackel29/ece551/"

# %%
df_small_noise_url_suffix = "main/busvoltage_smoothed.csv"
#df_small_noise_url_suffix = "main/busvoltage_smoothed_end_112707.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(df_small_noise_url, parse_dates=True, index_col=0)
df_small_noise_original = df_small_noise
#df_small_noise_section = df_small_noise[:10000] # smoothed bus voltage from 2001 to 2005
df_small_noise_section = df_small_noise[37570:44870] # smoothed bus voltage from early-2014 to mid-2016
df_small_noise_original = df_small_noise
df_small_noise = df_small_noise_section

# %%
df_daily_jumpsup_url_suffix = "main/busvoltage_without_anomaly.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(df_daily_jumpsup_url, parse_dates=True, index_col=0)
df_daily_jumpsup_original = df_daily_jumpsup
#df_daily_jumpsup_section = df_daily_jumpsup[:20009] # bus voltage from 2001 to 2008
df_daily_jumpsup_section = df_daily_jumpsup[37570:] # bus voltage from early-2014 to 2018
df_daily_jumpsup = df_daily_jumpsup_section

# %%
print(df_small_noise.head())
df_small_noise.shape
# Out:
#                      busvoltage
# datetime
# 2013-12-01 03:00:00   32.642355
# 2013-12-01 06:00:00   32.710191
# 2013-12-01 09:00:00   33.065461
# 2013-12-01 12:00:00   32.543526
# 2013-12-01 15:00:00   32.552189
# (7300, 1)

# %%
print(df_daily_jumpsup.head())
df_daily_jumpsup.shape
# Out:
#                      busvoltage
# datetime
# 2013-12-01 03:00:00   32.642355
# 2013-12-01 06:00:00   32.710191
# 2013-12-01 09:00:00   33.065461
# 2013-12-01 12:00:00   32.543526
# 2013-12-01 15:00:00   32.552189
# (14134, 1)

# %%
fig, ax = plt.subplots()
df_daily_jumpsup_original.plot(ax=ax)
plt.legend(["Unmodified original bus voltage telemetry from 2001 to 2018"])
plt.ylim(18,36)
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()

# %% [markdown]
# <br>The satellite telemetry from approximately 2008 through 2018 is used for training data.<br>

# %%
fig, ax = plt.subplots()
df_small_noise.plot(ax=ax)
plt.legend(["Training data is {}% of testing data".format(int(100*df_small_noise.shape[0]/df_daily_jumpsup.shape[0]))])
plt.ylim(25,35)
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()

# %% [markdown]
# <br>The entire satellite bus voltage telemetry from 2001 to 2018 has numerous spikes including a 20 volt drop near 2005. Let us see if the model will detect any of the spikes as an anomaly.<br>

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(ax=ax)
plt.legend(["Testing data is {}% of original data".format(int(100*df_daily_jumpsup_section.shape[0]/51704))])
plt.ylim(25,35)
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()

# %% [markdown]
# <br>Prepare training data<br><br>
# Get data values from the training timeseries data file and normalize the<br>
# `value` data. We have a `value` for every 3 hours for about 18 years.<br>
# -   24 hours / 3 hours = 8 timesteps per day<br>
# -  8 x 365 x 18 = 52560 data points in total<br>
# - Our dataset is 51704 data points, which is about 17.7 years total.<br>

# %% [markdown]
# Normalize the data by using the standardize method to create standard scores.<br><br>
# The formula is:<br><br>
# standard score = (original value - mean of entire dataset) / standard deviation of entire dataset<br>

# %%
training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
df_training_value = (df_small_noise - training_mean) / training_std
print("Number of training samples:", len(df_training_value))
# Out:
# Number of training samples: 7300

# %% [markdown]
# <br>Create sequences<br><br>
# Create sequences combining `TIME_STEPS` contiguous data values from the<br>
# training data.<br>

# %%
TIME_STEPS = 8 # each measurement is taken every 3 hours, so there are 8 samples per day, 56 samples per week, 2912 per year

# %% [markdown]
# Generated training sequences for use in the model.

# %%
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)

# %%
x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (7293, 8, 1)

# %% [markdown]
# <br>Build a model<br><br>
# We will build a convolutional reconstruction autoencoder model. The model will<br>
# take input of shape `(batch_size, sequence_length, num_features)` and return<br>
# output of the same shape. In this case, `sequence_length` is 8 and<br>
# `num_features` is 1.<br>

# %%
model = keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
        layers.Conv1D(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1D(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 4, 32)             256
#
#  dropout_2 (Dropout)         (None, 4, 32)             0
#
#  conv1d_3 (Conv1D)           (None, 2, 16)             3600
#
#  conv1d_transpose_3 (Conv1DT  (None, 4, 16)            1808
#  ranspose)
#
#  dropout_3 (Dropout)         (None, 4, 16)             0
#
#  conv1d_transpose_4 (Conv1DT  (None, 8, 32)            3616
#  ranspose)
#
#  conv1d_transpose_5 (Conv1DT  (None, 8, 1)             225
#  ranspose)
#
# =================================================================
# Total params: 9,505
# Trainable params: 9,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br>Train the model<br><br>
# Please note that we are using `x_train` as both the input and the target<br>
# since this is a reconstruction model.<br>

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=100,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, mode="min")
    ],
)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 1s 9ms/step - loss: 0.4989 - val_loss: 0.0139
# Epoch 2/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1281 - val_loss: 0.0125
# Epoch 3/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1141 - val_loss: 0.0090
# Epoch 4/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1022 - val_loss: 0.0067
# Epoch 5/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0854 - val_loss: 0.0054
# Epoch 6/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0051
# Epoch 7/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0649 - val_loss: 0.0053
# Epoch 8/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0599 - val_loss: 0.0053
# Epoch 9/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0549 - val_loss: 0.0049
# Epoch 10/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0523 - val_loss: 0.0055
# Epoch 11/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0486 - val_loss: 0.0055
# Epoch 12/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0466 - val_loss: 0.0051
# Epoch 13/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0447 - val_loss: 0.0055
# Epoch 14/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0426 - val_loss: 0.0048
# Epoch 15/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0395 - val_loss: 0.0048
# Epoch 16/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0389 - val_loss: 0.0044
# Epoch 17/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0382 - val_loss: 0.0044
# Epoch 18/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0351 - val_loss: 0.0042
# Epoch 19/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.0054
# Epoch 20/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0039
# Epoch 21/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0311 - val_loss: 0.0057
# Epoch 22/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0301 - val_loss: 0.0045
# Epoch 23/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0284 - val_loss: 0.0045
# Epoch 24/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0281 - val_loss: 0.0045
# Epoch 25/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0280 - val_loss: 0.0046
# Epoch 26/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0278 - val_loss: 0.0053
# Epoch 27/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0262 - val_loss: 0.0043
# Epoch 28/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0269 - val_loss: 0.0032
# Epoch 29/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0257 - val_loss: 0.0050
# Epoch 30/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0251 - val_loss: 0.0031
# Epoch 31/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0235 - val_loss: 0.0030
# Epoch 32/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0243 - val_loss: 0.0032
# Epoch 33/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0238 - val_loss: 0.0035
# Epoch 34/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0235 - val_loss: 0.0040
# Epoch 35/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0046
# Epoch 36/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0230 - val_loss: 0.0030
# Epoch 37/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0224 - val_loss: 0.0027
# Epoch 38/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0216 - val_loss: 0.0028
# Epoch 39/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0214 - val_loss: 0.0031
# Epoch 40/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0222 - val_loss: 0.0025
# Epoch 41/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0031
# Epoch 42/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0205 - val_loss: 0.0026
# Epoch 43/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0210 - val_loss: 0.0026
# Epoch 44/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0201 - val_loss: 0.0025
# Epoch 45/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0204 - val_loss: 0.0029
# Epoch 46/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0197 - val_loss: 0.0026
# Epoch 47/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0199 - val_loss: 0.0024
# Epoch 48/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0202 - val_loss: 0.0035
# Epoch 49/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0193 - val_loss: 0.0022
# Epoch 50/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0184 - val_loss: 0.0029
# Epoch 51/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0186 - val_loss: 0.0023
# Epoch 52/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0192 - val_loss: 0.0025
# Epoch 53/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0188 - val_loss: 0.0021
# Epoch 54/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0188 - val_loss: 0.0021
# Epoch 55/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0185 - val_loss: 0.0026
# Epoch 56/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0179 - val_loss: 0.0022
# Epoch 57/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0183 - val_loss: 0.0024
# Epoch 58/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0180 - val_loss: 0.0035
# Epoch 59/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0181 - val_loss: 0.0022
# Epoch 60/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0173 - val_loss: 0.0019
# Epoch 61/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0175 - val_loss: 0.0025
# Epoch 62/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0170 - val_loss: 0.0020
# Epoch 63/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0173 - val_loss: 0.0022
# Epoch 64/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0167 - val_loss: 0.0021
# Epoch 65/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0161 - val_loss: 0.0021
# Epoch 66/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0168 - val_loss: 0.0024
# Epoch 67/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0165 - val_loss: 0.0022
# Epoch 68/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0170 - val_loss: 0.0025
# Epoch 69/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0020
# Epoch 70/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0023
# Epoch 71/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0018
# Epoch 72/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0159 - val_loss: 0.0020
# Epoch 73/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0162 - val_loss: 0.0020
# Epoch 74/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0161 - val_loss: 0.0020
# Epoch 75/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0166 - val_loss: 0.0021
# Epoch 76/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0154 - val_loss: 0.0020
# Epoch 77/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0020
# Epoch 78/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0020
# Epoch 79/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0020
# Epoch 80/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0019
# Epoch 81/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0019
# Epoch 82/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0020
# Epoch 83/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0155 - val_loss: 0.0021
# Epoch 84/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0021
# Epoch 85/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0021
# Epoch 86/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0020
# Epoch 87/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0149 - val_loss: 0.0020
# Epoch 88/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0154 - val_loss: 0.0019
# Epoch 89/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0153 - val_loss: 0.0019
# Epoch 90/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0143 - val_loss: 0.0019
# Epoch 91/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0024
# Epoch 92/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0142 - val_loss: 0.0017
# Epoch 93/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0022
# Epoch 94/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0026
# Epoch 95/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0022
# Epoch 96/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0018
# Epoch 97/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0021
# Epoch 98/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0135 - val_loss: 0.0021
# Epoch 99/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0018
# Epoch 100/100
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0019

# %% [markdown]
# <br>
# Let's plot training and validation loss to see how the training went.<br>

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# <br>Detecting anomalies<br><br>
# We will detect anomalies by determining how well our model can reconstruct<br>
# the input data.<br>
# 1.   Find Mean Absolute Error (MAE) loss on training samples.<br>
# 2.   Find max MAE loss value. This is the worst our model has performed trying<br>
# to reconstruct a sample. We will make this the `threshold` for anomaly<br>
# detection.<br>
# 3.   If the reconstruction loss for a sample is greater than this `threshold`<br>
# value then we can infer that the model is seeing a pattern that it isn't<br>
# familiar with. We will label this sample as an `anomaly`.<br>

# %% [markdown]
# Get train MAE loss.

# %%
x_train_pred = model.predict(x_train)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)
# Out:
# 228/228 [==============================] - 1s 3ms/step

# %%
plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# %% [markdown]
# Get reconstruction loss threshold.

# %%
threshold = np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)
# Out:
# Reconstruction error threshold:  0.6800695697263768

# %% [markdown]
# <br>Compare recontruction<br>
# As a test, we can see how our model has recontructed the first sample. This is the 8 timesteps in the first 24 hours of our training dataset because a measurement is recorded once every 3 hours.<br>

# %% [markdown]
# Checking how the first sequence is learned

# %%
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# <br>Prepare test data<br>

# %%
df_test_value = (df_daily_jumpsup - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# Create sequences from test values.

# %%
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Test input shape:  (14127, 8, 1)

# %%
x_test
# Out:
# array([[[-1.37470165],
#         [-1.25130782],
#         [-0.60506447],
#         ...,
#         [-1.45596128],
#         [-0.96730797],
#         [-1.23944745]],
#
#        [[-1.25130782],
#         [-0.60506447],
#         [-1.55447487],
#         ...,
#         [-0.96730797],
#         [-1.23944745],
#         [-1.54094664]],
#
#        [[-0.60506447],
#         [-1.55447487],
#         [-1.53871654],
#         ...,
#         [-1.23944745],
#         [-1.54094664],
#         [-1.49743492]],
#
#        ...,
#
#        [[-3.32115181],
#         [-3.38275008],
#         [-3.35086944],
#         ...,
#         [-3.33942437],
#         [-3.37920559],
#         [-3.32767148]],
#
#        [[-3.38275008],
#         [-3.35086944],
#         [-3.34156677],
#         ...,
#         [-3.37920559],
#         [-3.32767148],
#         [-3.35725396]],
#
#        [[-3.35086944],
#         [-3.34156677],
#         [-3.32941089],
#         ...,
#         [-3.32767148],
#         [-3.35725396],
#         [-3.38690388]]])

# %% [markdown]
# Get test MAE loss.

# %%
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))
# Out:
# 442/442 [==============================] - 1s 2ms/step

# %%
plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# %% [markdown]
# Detect all the samples which are anomalies.

# %%
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Number of anomaly samples:  67
# Indices of anomaly samples:  (array([ 2953,  2955,  3234,  3235,  3237,  3238, 11798, 11799, 11800,
#        11801, 11802, 11803, 11804, 11805, 11806, 11807, 11808, 11809,
#        11810, 11811, 11812, 11813, 11814, 11815, 11824, 11825, 11826,
#        11827, 11828, 11829, 11830, 11831, 11851, 11866, 11903, 11904,
#        11905, 11906, 11907, 11908, 11909, 11910, 11911, 11970, 11971,
#        12010, 12011, 12012, 12013, 12014, 12015, 12016, 12017, 12107,
#        12108, 12112, 12118, 12119, 12120, 12121, 12122, 12123, 12124,
#        12125, 12126, 12127, 12128]),)

# %% [markdown]
# <br>Plot anomalies<br><br>
# We now know the samples of the data which are anomalies. With this, we will<br>
# find the corresponding `timestamps` from the original test data. We will be<br>
# using the following method to do that:<br><br>
# Let's say time_steps = 3 and we have 10 training values. Our `x_train` will<br>
# look like this:<br>
# - 0, 1, 2<br>
# - 1, 2, 3<br>
# - 2, 3, 4<br>
# - 3, 4, 5<br>
# - 4, 5, 6<br>
# - 5, 6, 7<br>
# - 6, 7, 8<br>
# - 7, 8, 9<br><br>
# All except the initial and the final time_steps-1 data values, will appear in<br>
# `time_steps` number of samples. So, if we know that the samples<br>
# [(3, 4, 5), (4, 5, 6), (5, 6, 7)] are anomalies, we can say that the data point<br>
# 5 is an anomaly.<br>

# %% [markdown]
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies

# %%
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
if len(anomalous_data_indices) == 0:
    print("No anomalies detected by model.")

# %% [markdown]
# <br>We can overlay the anomalies on the original test data plot shown in red.<br>

# %%
if len(anomalous_data_indices) > 0:
    df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]
    df_subset.columns=["Anomaly Voltage"]
    df_daily_jumpsup.columns=["Original Bus Voltage"]
    fig, ax = plt.subplots()
    df_daily_jumpsup.plot(ax=ax) # removed legend=False
    df_subset.plot(ax=ax, color="m")
    plt.legend()
    plt.ylabel("Bus Voltage (volts)")
    plt.xlabel("Time (year)")
    plt.show()

# %%
anomalous_data_indices
# Out:
# [11805,
#  11806,
#  11807,
#  11808,
#  11809,
#  11810,
#  11811,
#  11812,
#  11813,
#  11814,
#  11815,
#  11816,
#  11831,
#  11832,
#  11910,
#  11911,
#  11912,
#  12017,
#  12018,
#  12125,
#  12126,
#  12127,
#  12128,
#  12129]

# %%
df_subset
# Out:
#                      Anomaly Voltage
# datetime
# 2017-12-15 18:00:00        28.309448
# 2017-12-15 21:00:00        28.463377
# 2017-12-16 00:00:00        28.617306
# 2017-12-16 03:00:00        28.771234
# 2017-12-16 06:00:00        28.925163
# 2017-12-16 09:00:00        29.079092
# 2017-12-16 12:00:00        29.233020
# 2017-12-16 15:00:00        29.386949
# 2017-12-16 18:00:00        29.540878
# 2017-12-16 21:00:00        29.694806
# 2017-12-17 00:00:00        29.848735
# 2017-12-17 03:00:00        30.002664
# 2017-12-19 00:00:00        28.223747
# 2017-12-19 03:00:00        26.580540
# 2017-12-28 21:00:00        25.853323
# 2017-12-29 00:00:00        27.329939
# 2017-12-29 03:00:00        28.806554
# 2018-01-11 06:00:00        29.204498
# 2018-01-11 09:00:00        28.693274
# 2018-01-24 18:00:00        30.175352
# 2018-01-24 21:00:00        28.135707
# 2018-01-25 00:00:00        26.096062
# 2018-01-25 03:00:00        27.300416
# 2018-01-25 06:00:00        28.504770

# %%
x_train.shape[0], x_train.shape[1], x_train.shape[2]
# Out:
# (7293, 8, 1)

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
df_subset.columns=["Anomaly Voltage 2nd Experiment"]
df_subset_first.columns=["Anomaly Voltage 1st Experiment"]
df_daily_jumpsup_original.columns=["Original Bus Voltage"]
fig, ax = plt.subplots()
df_daily_jumpsup_original.plot(ax=ax) # removed legend=False
df_subset.plot(ax=ax, color="m")
df_subset_first.plot(ax=ax, color="r")
plt.legend()
plt.ylabel("Bus Voltage (volts)")
plt.xlabel("Time (year)")
plt.show()
